# %%
import numpy as np
import pandas as pd

# %%
new_geo_df = pd.read_json("C:\\Users\\Jeff\Documents\\BootCamp\\Project_2\\gz_2010_us_050_00_5m.json")

# %%
new_geo_df.head()
# Out:
#                                             features               type
# 0  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 1  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 2  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 3  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 4  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection

# %%
old_geo_df = pd.read_json("us_states_geo.json")

# %%
old_geo_df.head()
# Out:
#                                             features               type
# 0  {'type': 'Feature', 'id': 'AL', 'properties': ...  FeatureCollection
# 1  {'type': 'Feature', 'id': 'AK', 'properties': ...  FeatureCollection
# 2  {'type': 'Feature', 'id': 'AZ', 'properties': ...  FeatureCollection
# 3  {'type': 'Feature', 'id': 'AR', 'properties': ...  FeatureCollection
# 4  {'type': 'Feature', 'id': 'CA', 'properties': ...  FeatureCollection

# %%
data_df = pd.read_csv("C:\\Users\\Jeff\Documents\\BootCamp\\Project_2\\acs2015_county_data_v2.csv")

# %%
data_df.head()
# Out:
#            GEO_ID  TotalPop    Men  Women  Hispanic  White  Black  Native  \
# 0  0500000US01001     55221  26745  28476       2.6   75.8   18.5     0.4
# 1  0500000US01003    195121  95314  99807       4.5   83.1    9.5     0.6
# 2  0500000US01005     26932  14497  12435       4.6   46.2   46.7     0.2
# 3  0500000US01007     22604  12073  10531       2.2   74.5   21.4     0.4
# 4  0500000US01009     57710  28512  29198       8.6   87.9    1.5     0.3
#
#    Asian  Pacific      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0    1.0      0.0      ...        0.5          1.3         1.8         26.5
# 1    0.7      0.0      ...        1.0          1.4         3.9         26.4
# 2    0.4      0.0      ...        1.8          1.5         1.6         24.1
# 3    0.1      0.0      ...        0.6          1.5         0.7         28.8
# 4    0.1      0.0      ...        0.9          0.4         2.3         34.9
#
# ...

# %%
# joined_table = new_geo_df.set_index(['features']['properties']["GEO_ID"]).join(data_df.set_index("GEO_ID"))

# %%
# new_geo_df[1]["properties"]['GEO_ID']

# %%
#     for rows in new_geo_df['features']:
#         print(rows['properties']['GEO_ID'])
#         print(row.index[1])

# %%
counter =0
for i in new_geo_df['features'][counter]['properties'].rows():
    print (i)
    counter +=1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-281-21ffe3e34156> in <module>()
#       1 counter =0
# ----> 2 for i in new_geo_df['features'][counter]['properties'].rows():
#       3     print (i)
#       4     counter +=1
#
# AttributeError: 'dict' object has no attribute 'rows'

# %%
# features_new_df = new_geo_df['features']
# prop = [li['properties'] for li in features_new_df] 
# for row in prop:
#     prop.update({'newkey':'value'})
#     print (row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-297-27305e261789> in <module>()
#       2 prop = [li['properties'] for li in features_new_df]
#       3 for row in prop:
# ----> 4     prop.update({'newkey':'value'})
#       5 #     print (row)
#
# AttributeError: 'list' object has no attribute 'update'

# %%
# index=0
# for index in range(len(new_geo_df['features'])):
#     for key in new_geo_df['features'][index]:
# #         print (new_geo_df['features'][index][key])
#         if new_geo_df['features'][index]['properties']['GEO_ID'] == '0500000US02270':
#             new_geo_df['features'][index]['properties'].update({'newkey':'value'})
#     index +=1
# Out:
# weeeeeeee
# weeeeeeee
# weeeeeeee

# %%
counter = 0
for index, row in data_df.iterrows():
    curr_geo_id = row['GEO_ID']
    for index in range(len(new_geo_df['features'])):
        for key in new_geo_df['features'][index]:
            if new_geo_df['features'][index]['properties']['GEO_ID'] == curr_geo_id:
                new_geo_df['features'][index]['properties'].update({'newkey':'value'})
        index +=1
counter +=1
print(counter)
# Out:
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# weeeeeeee
# ...

# %%
new_geo_df.features[100]
# Out:
# {'geometry': {'coordinates': [[[-85.434045, 32.40984],
#     [-85.433543, 32.234648],
#     [-85.856218, 32.231975],
#     [-85.862601, 32.234915],
#     [-85.87606099999999, 32.246344],
#     [-85.877868, 32.291528],
#     [-85.898539, 32.305289],
#     [-85.898689, 32.274987],
#     [-85.919293, 32.274382],
#     [-85.920489, 32.280699],
#     [-85.940602, 32.287447],
#     [-85.954133, 32.301847],
#     [-85.959387, 32.324026],
#     [-85.969623, 32.333627],
#     [-85.992376, 32.338172],
#     [-86.023012, 32.419978],
#     [-85.990652, 32.433053],
#     [-85.992142, 32.452498],
#     [-85.985262, 32.440472],
#     [-85.973455, 32.453453],
#     [-85.958953, 32.44113],
#     [-85.931776, 32.453528],
#     [-85.89442, 32.447578],
#     [-85.879254, 32.449784],
#     [-85.872695, 32.473869],
#     [-85.852625, 32.475747],
#     [-85.886148, 32.493053],
#     [-85.797156, 32.494236],
#     [-85.798585, 32.581089],
#     [-85.712654, 32.581834],
#     [-85.712756, 32.595731],
# ...

# %%
# print([x.items() for x in new_geo_df['features'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-294-8c913a31d783> in <module>()
# ----> 1 print([x.items() for x in new_geo_df['features'][1]['properties']])
#       2
#
# <ipython-input-294-8c913a31d783> in <listcomp>(.0)
# ----> 1 print([x.items() for x in new_geo_df['features'][1]['properties']])
#       2
#
# AttributeError: 'str' object has no attribute 'items'

# %%
#new_geo_df['features'][1]["properties"]['GEO_ID']
counter=0
title_index = 0
for index, row in data_df.iterrows():
    curr_geo_id = row['GEO_ID']
#     print(curr_geo_id)
    for rows in new_geo_df['features']:
#         print(rows['properties']['GEO_ID'])
        if rows['properties']['GEO_ID']== curr_geo_id:
#             print("yay a match")
#         else:
#             print(row
            for titles in range(34):
#                   rows['properties'][row.index[titles+1]]=row[titles+1]
                rows['properties'].update({row.index[titles+1]:row[titles+1]})
#                 print(titles)
                
#             for titles in row.index:
#             data.update({row[titles]:})
#             rows['properties'].update({})
            
#     print(row['properties']['GEO_ID'])
#new_geo_df[1]['properties']['GEO_ID']

# %%
new_geo_df.features[10]
# Out:
# {'geometry': {'coordinates': [[[-92.24052, 35.71219],
#     [-91.837179, 35.704932],
#     [-91.789823, 35.711734],
#     [-91.793958, 35.534114],
#     [-91.795855, 35.455574],
#     [-91.819339, 35.449872],
#     [-91.829398, 35.45455],
#     [-91.836816, 35.441001],
#     [-91.850144, 35.436442],
#     [-91.851958, 35.358287],
#     [-92.111463, 35.362725],
#     [-92.252759, 35.363718],
#     [-92.248506, 35.537922],
#     [-92.244721, 35.537933],
#     [-92.24052, 35.71219]]],
#   'type': 'Polygon'},
#  'properties': {'CENSUSAREA': 553.692,
#   'COUNTY': '023',
#   'GEO_ID': '0500000US05023',
#   'LSAD': 'County',
#   'NAME': 'Cleburne',
#   'STATE': '05',
#   'newkey': 'value'},
#  'type': 'Feature'}

# %%
# build_df = pd.DataFrame(columns =['CENSUSAREA','COUNTY','GEO_ID','LSAD','NAME','STATE'])

# %%
# build_df
# Out:
# Empty DataFrame
# Columns: [CENSUSAREA, COUNTY, GEO_ID, LSAD, NAME, STATE]
# Index: []

# %%
# Out:
# ['CENSUSAREA', 'COUNTY', 'GEO_ID', 'LSAD', 'NAME', 'STATE']

# %%
# for rows in new_geo_df:
#     build_df['CENSUSAREA'] = new_geo_df[rows]['properties']['CENSUSAREA']
#     build_df['CENSUSAREA'] = new_geo_df[rows]['properties']['CENSUSAREA']

# %%
# joined_table = new_geo_df.set_index(['features']['properties']["GEO_ID"]).join(data_df.set_index("GEO_ID"))

# %%
# new_geo_df['features'][1]['properties']['NAME']
# Out:
# 'Wade Hampton'

# %%
# import json

# %%
# with open("C:\\Users\\Jeff\Documents\\BootCamp\\Project_2\\gz_2010_us_050_00_5m.json") as datafile:
#     data = json.load(datafile)
# js_df = pd.DataFrame(data)

# %%
# js_df.head()
# Out:
#                                             features               type
# 0  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 1  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 2  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 3  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 4  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection

# %%
# new_geo_df.head()
# Out:
#                                             features               type
# 0  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 1  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 2  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 3  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 4  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection

# %%
# new_geo_df['features'][1]['properties']['GEO_ID']
# Out:
# '0500000US02270'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-6167a11c57fa> in <module>()
# ----> 1 new_geo_df['features']['properties']
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
# ...

# %%
# geo_df = pd.read_json("C:\\Users\\Jeff\Documents\\BootCamp\\Project_2\\gz_2010_us_050_00_5m.json")

# %%
# geo_df.head()
# Out:
#                                             features               type
# 0  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 1  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 2  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 3  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection
# 4  {'type': 'Feature', 'properties': {'GEO_ID': '...  FeatureCollection

# %%
# geo_df.features
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-221-4785086742c8> in <module>()
# ----> 1 geo_df.features['properties']
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
# ...

# %%
# data_df
# Out:
#               GEO_ID  TotalPop     Men   Women  Hispanic  White  Black  \
# 0     0500000US01001     55221   26745   28476       2.6   75.8   18.5
# 1     0500000US01003    195121   95314   99807       4.5   83.1    9.5
# 2     0500000US01005     26932   14497   12435       4.6   46.2   46.7
# 3     0500000US01007     22604   12073   10531       2.2   74.5   21.4
# 4     0500000US01009     57710   28512   29198       8.6   87.9    1.5
# 5     0500000US01011     10678    5660    5018       4.4   22.2   70.7
# 6     0500000US01013     20354    9502   10852       1.2   53.3   43.8
# 7     0500000US01015    116648   56274   60374       3.5   73.0   20.3
# 8     0500000US01017     34079   16258   17821       0.4   57.3   40.3
# 9     0500000US01019     26008   12975   13033       1.5   91.7    4.8
# 10    0500000US01021     43819   21619   22200       7.6   80.5   10.2
# 11    0500000US01023     13395    6382    7013       0.4   55.9   42.9
# ...

# %%
# joined_table=df.set_index('GEO_ID').join(data_df.set_index('GEO_ID'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GEO_ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-3c62fa9b44e5> in <module>()
# ...
